# %%
# Read the CSV files
import pandas as pd
import numpy as np

df=pd.read_csv('exams.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      male        group A                 high school      standard
# 1    female        group D            some high school  free/reduced
# 2      male        group E                some college  free/reduced
# 3      male        group B                 high school      standard
# 4      male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                 high school      standard
# 996    male        group D          associate's degree  free/reduced
# 997  female        group C            some high school  free/reduced
# 998  female        group C                some college      standard
# 999    male        group A                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

df_num_cat= pd.DataFrame()

df_num_cat['gender'] = enc.fit_transform(df['gender'])
df_num_cat['race/ethnicity'] = enc.fit_transform(df['race/ethnicity'])
df_num_cat['parental level of education'] = enc.fit_transform(df['parental level of education'])
df_num_cat['lunch'] = enc.fit_transform(df['lunch'])
df_num_cat['test preparation course'] = enc.fit_transform(df['test preparation course'])
df_num_cat['math score'] = enc.fit_transform(df['math score'])
df_num_cat['reading score'] = enc.fit_transform(df['reading score'])
df_num_cat['writing score'] = enc.fit_transform(df['writing score'])
df_num_cat
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               0                            2      1
# 1         0               3                            5      0
# 2         1               4                            4      0
# 3         1               1                            2      1
# 4         1               4                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            2      1
# 996       1               3                            0      0
# 997       0               2                            5      0
# 998       0               2                            4      1
# 999       1               0                            4      1
#
#      test preparation course  math score  reading score  writing score
# 0                          0          43             39             38
# ...

# %%
X=df_num_cat.drop(['writing score'],axis=1)
y=df_num_cat['writing score']
print(X)
print(y)
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0         1               0                            2      1
# 1         0               3                            5      0
# 2         1               4                            4      0
# 3         1               1                            2      1
# 4         1               4                            0      1
# ..      ...             ...                          ...    ...
# 995       1               2                            2      1
# 996       1               3                            0      0
# 997       0               2                            5      0
# 998       0               2                            4      1
# 999       1               0                            4      1
#
#      test preparation course  math score  reading score
# 0                          0          43             39
# 1                          1          16             31
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

dt_clf = DecisionTreeClassifier(criterion='entropy')
dt_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
dt_clf.score(X,y)
y_pred=dt_clf.predict(X)
print(y)
print(y_pred)
# Out:
# 0      38
# 1      30
# 2      25
# 3      43
# 4      43
#        ..
# 995    40
# 996    67
# 997    16
# 998    57
# 999    37
# Name: writing score, Length: 1000, dtype: int64
# [38 30 25 43 43 51 38 59 40 20 60 65 60 48 60 32 17 40 19  6 63 30 48 29
#   7 17 31 35 64 26 52 48 14 46 64 49 50 29 48 52 47 39 57 45 62 26 32 53
#  48 32 39 35 60 24 22 37 59 58 26 23 43 34 37 53 72 45 31 24 35 32 48 22
#  38 56 42 45 34 56 51 20 37 17 34 48 14 44 44 63 36 47 17 45 62 68 47 42
#  75 24 24 28 37 54 52 42 33 57 48 19 46  8 61 22 46  8 49 51 38 30 33 62
#  46 64 37 20 61 33 39 20 62 75 57 39 32 31 29 44 51 43 24 39 32 58 62 35
#  43 32 41 21 75 19 55 34 51 48 33 22 34 62 68 54 72 40 66 50 45 67 33 43
#  68 58 34 51 46 37 47 35 31 26 70 61 39 24 64 51 62 74 42 34 39 28 28 26
#  36 64 41 23 23 26 45 40 40 22 45 42 57 50 59 56 59 41 43 60 45 39 52 35
#  41 52 43 37 58 49 19 58 72 47 14 48 56 57 53 45  8 47 57 65 39 71 39 50
# ...

# %%
from sklearn import tree
tree.plot_tree(dt_clf)
plt.show()
